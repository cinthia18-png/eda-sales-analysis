# %%
# Exploratory Data Analysis – Amazon Sales
## 1. Introduction
This notebook presents an exploratory data analysis of Amazon sales data to understand product performance and sales trends.
## 2. Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
df = pd.read_csv("data/amazon_sale_report.csv")
df.head()
